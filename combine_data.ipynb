# %%
#import dependencies
import pandas as pd

# %%
# Read data from file 'filename.csv' 
led = pd.read_csv("Resources/Data/life_expectancy.csv") 
alc_con = pd.read_csv("Resources/Data/world_alcohol_consumption.csv")
happiness = pd.read_csv("Resources/Data/world_happiness_2020.csv")
# Preview the first 5 lines of the loaded data 
print(led.columns)
print(alc_con.columns)
print(happiness.columns)
# Out:
# Index(['Country', 'Year', 'Status', 'Lifeexpectancy', 'AdultMortality',
#        'infantdeaths', 'Alcohol', 'percentageexpenditure', 'HepatitisB',
#        'Measles', 'BMI', 'under-fivedeaths', 'Polio', 'Totalexpenditure',
#        'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'thinness1-19years',
#        'thinness5-9years', 'Incomecompositionofresources', 'Schooling'],
#       dtype='object')
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol'],
#       dtype='object')
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
# Combine the data into a single dataset
led = led.loc[led['Year']==2015]
led['Country'].value_counts()
# Out:
# Congo               2
# Uzbekistan          1
# Mexico              1
# Swaziland           1
# Brunei              1
#                    ..
# Yemen               1
# Papua New Guinea    1
# Latvia              1
# Nigeria             1
# Ecuador             1
# Name: Country, Length: 182, dtype: int64

# %%
alc_con=alc_con.rename(columns={'country':'Country'})
happiness = happiness.rename(columns={'Country name': 'Country'})
happiness.head()
# Out:
#        Country Regional indicator  Ladder score  \
# 0      Finland     Western Europe        7.8087
# 1      Denmark     Western Europe        7.6456
# 2  Switzerland     Western Europe        7.5599
# 3      Iceland     Western Europe        7.5045
# 4       Norway     Western Europe        7.4880
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031156      7.869766      7.747634
# 1                        0.033492      7.711245      7.579955
# 2                        0.035014      7.628528      7.491272
# 3                        0.059616      7.621347      7.387653
# 4                        0.034837      7.556281      7.419719
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0              10.639267        0.954330                71.900825
# 1              10.774001        0.955991                72.402504
# 2              10.979933        0.942847                74.102448
# 3              10.772559        0.974670                73.000000
# 4              11.087804        0.952487                73.200783
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                      0.949172   -0.059482                   0.195445
# 1                      0.951444    0.066202                   0.168489
# 2                      0.921337    0.105911                   0.303728
# 3                      0.948892    0.246944                   0.711710
# 4                      0.955750    0.134533                   0.263218
#
#    Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 0                  1.972317                          1.285190
# 1                  1.972317                          1.326949
# 2                  1.972317                          1.390774
# 3                  1.972317                          1.326502
# 4                  1.972317                          1.424207
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                      1.499526                               0.961271
# 1                      1.503449                               0.979333
# 2                      1.472403                               1.040533
# 3                      1.547567                               1.000843
# 4                      1.495173                               1.008072
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                    0.662317                  0.159670
# 1                                    0.665040                  0.242793
# 2                                    0.628954                  0.269056
# 3                                    0.661981                  0.362330
# 4                                    0.670201                  0.287985
#
#    Explained by: Perceptions of corruption  Dystopia + residual
# 0                                 0.477857             2.762835
# 1                                 0.495260             2.432741
# 2                                 0.407946             2.350267
# 3                                 0.144541             2.460688
# 4                                 0.434101             2.168266

# %%
led
# Out:
#                 Country  Year      Status  Lifeexpectancy  AdultMortality  \
# 0           Afghanistan  2015  Developing            65.0           263.0
# 16              Albania  2015  Developing            77.8            74.0
# 32              Algeria  2015  Developing            75.6            19.0
# 48               Angola  2015  Developing            52.4           335.0
# 64    Antigua & Barbuda  2015  Developing            76.4            13.0
# ...                 ...   ...         ...             ...             ...
# 2858          Venezuela  2015  Developing            74.1           157.0
# 2874            VietNam  2015  Developing            76.0           127.0
# 2890              Yemen  2015  Developing            65.7           224.0
# 2906             Zambia  2015  Developing            61.8            33.0
# 2922           Zimbabwe  2015  Developing            67.0           336.0
#
#       infantdeaths  Alcohol  percentageexpenditure  HepatitisB  Measles  ...  \
# 0               62     0.01              71.279624        65.0     1154  ...
# 16               0     4.60             364.975229        99.0        0  ...
# 32              21      NaN               0.000000        95.0       63  ...
# 48              66      NaN               0.000000        64.0      118  ...
# 64               0      NaN               0.000000        99.0        0  ...
# ...            ...      ...                    ...         ...      ...  ...
# 2858             9      NaN               0.000000        87.0        0  ...
# 2874            28      NaN               0.000000        97.0      256  ...
# 2890            37      NaN               0.000000        69.0      468  ...
# 2906            27      NaN               0.000000         9.0        9  ...
# 2922            22      NaN               0.000000        87.0        0  ...
#
#       Polio  Totalexpenditure  Diphtheria  HIV/AIDS           GDP  Population  \
# 0       6.0              8.16        65.0       0.1    584.259210  33736494.0
# 16     99.0              6.00        99.0       0.1   3954.227830     28873.0
# 32     95.0               NaN        95.0       0.1   4132.762920  39871528.0
# 48      7.0               NaN        64.0       1.9   3695.793748   2785935.0
# 64     86.0               NaN        99.0       0.2  13566.954100         NaN
# ...     ...               ...         ...       ...           ...         ...
# 2858   87.0               NaN        87.0       0.1           NaN         NaN
# 2874   97.0               NaN        97.0       0.1           NaN         NaN
# 2890   63.0               NaN        69.0       0.1           NaN         NaN
# 2906    9.0               NaN         9.0       4.1   1313.889646    161587.0
# 2922   88.0               NaN        87.0       6.2    118.693830  15777451.0
#
#       thinness1-19years  thinness5-9years  Incomecompositionofresources  \
# 0                  17.2              17.3                         0.479
# 16                  1.2               1.3                         0.762
# 32                  6.0               5.8                         0.743
# 48                  8.3               8.2                         0.531
# 64                  3.3               3.3                         0.784
# ...                 ...               ...                           ...
# 2858                1.6               1.5                         0.769
# 2874               14.2              14.5                         0.678
# 2890               13.6              13.4                         0.499
# 2906                6.3               6.1                         0.576
# 2922                5.6               5.5                         0.507
#
#       Schooling
# 0          10.1
# 16         14.2
# 32         14.4
# 48         11.4
# 64         13.9
# ...         ...
# 2858       14.3
# 2874       12.6
# 2890        9.0
# 2906       12.5
# 2922       10.3
#
# [183 rows x 22 columns]

# %%
alc_con
# Out:
#          Country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol
# 0                             0.0
# 1                             4.9
# 2                             0.7
# 3                            12.4
# 4                             5.9
# ..                            ...
# 188                           7.7
# 189                           2.0
# 190                           0.1
# 191                           2.5
# 192                           4.7
#
# [193 rows x 5 columns]

# %%
happiness
happiness_clean = happiness[["Country", "Regional indicator", "Ladder score", "Logged GDP per capita", "Social support", "Healthy life expectancy", "Freedom to make life choices", "Generosity", "Perceptions of corruption", "Ladder score in Dystopia"]]
happiness_clean
# Out:
#                       Country  Regional indicator  Ladder score  \
# 0                     Finland      Western Europe        7.8087
# 1                     Denmark      Western Europe        7.6456
# 2                 Switzerland      Western Europe        7.5599
# 3                     Iceland      Western Europe        7.5045
# 4                      Norway      Western Europe        7.4880
# ..                        ...                 ...           ...
# 148  Central African Republic  Sub-Saharan Africa        3.4759
# 149                    Rwanda  Sub-Saharan Africa        3.3123
# 150                  Zimbabwe  Sub-Saharan Africa        3.2992
# 151               South Sudan  Sub-Saharan Africa        2.8166
# 152               Afghanistan          South Asia        2.5669
#
#      Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                10.639267        0.954330                71.900825
# 1                10.774001        0.955991                72.402504
# 2                10.979933        0.942847                74.102448
# 3                10.772559        0.974670                73.000000
# 4                11.087804        0.952487                73.200783
# ..                     ...             ...                      ...
# 148               6.625160        0.319460                45.200001
# 149               7.600104        0.540835                61.098846
# 150               7.865712        0.763093                55.617260
# 151               7.425360        0.553707                51.000000
# 152               7.462861        0.470367                52.590000
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                        0.949172   -0.059482                   0.195445
# 1                        0.951444    0.066202                   0.168489
# 2                        0.921337    0.105911                   0.303728
# 3                        0.948892    0.246944                   0.711710
# 4                        0.955750    0.134533                   0.263218
# ..                            ...         ...                        ...
# 148                      0.640881    0.082410                   0.891807
# 149                      0.900589    0.055484                   0.183541
# 150                      0.711458   -0.072064                   0.810237
# 151                      0.451314    0.016519                   0.763417
# 152                      0.396573   -0.096429                   0.933687
#
#      Ladder score in Dystopia
# 0                    1.972317
# 1                    1.972317
# 2                    1.972317
# 3                    1.972317
# 4                    1.972317
# ..                        ...
# 148                  1.972317
# 149                  1.972317
# 150                  1.972317
# 151                  1.972317
# 152                  1.972317
#
# [153 rows x 10 columns]

# %%
combined_df = pd.merge(alc_con,led, on="Country",how='outer')
combined_df
# Out:
#                            Country  beer_servings  spirit_servings  \
# 0                      Afghanistan            0.0              0.0
# 1                          Albania           89.0            132.0
# 2                          Algeria           25.0              0.0
# 3                          Andorra          245.0            138.0
# 4                           Angola          217.0             57.0
# ..                             ...            ...              ...
# 194                        Czechia            NaN              NaN
# 195  DemocraticPeople'sSouth Korea            NaN              NaN
# 196                    South Sudan            NaN              NaN
# 197                       SriLanka            NaN              NaN
# 198                        VietNam            NaN              NaN
#
#      wine_servings  total_litres_of_pure_alcohol    Year      Status  \
# 0              0.0                           0.0  2015.0  Developing
# 1             54.0                           4.9  2015.0  Developing
# 2             14.0                           0.7  2015.0  Developing
# 3            312.0                          12.4     NaN         NaN
# 4             45.0                           5.9  2015.0  Developing
# ..             ...                           ...     ...         ...
# 194            NaN                           NaN  2015.0   Developed
# 195            NaN                           NaN  2015.0  Developing
# 196            NaN                           NaN  2015.0  Developing
# 197            NaN                           NaN  2015.0  Developing
# 198            NaN                           NaN  2015.0  Developing
#
#      Lifeexpectancy  AdultMortality  infantdeaths  ...  Polio  \
# 0              65.0           263.0          62.0  ...    6.0
# 1              77.8            74.0           0.0  ...   99.0
# 2              75.6            19.0          21.0  ...   95.0
# 3               NaN             NaN           NaN  ...    NaN
# 4              52.4           335.0          66.0  ...    7.0
# ..              ...             ...           ...  ...    ...
# 194            78.8            86.0           0.0  ...   97.0
# 195            76.0           139.0           6.0  ...   99.0
# 196            57.3           332.0          26.0  ...   41.0
# 197            74.9           138.0           3.0  ...   99.0
# 198            76.0           127.0          28.0  ...   97.0
#
#      Totalexpenditure  Diphtheria  HIV/AIDS          GDP  Population  \
# 0                8.16        65.0       0.1   584.259210  33736494.0
# 1                6.00        99.0       0.1  3954.227830     28873.0
# 2                 NaN        95.0       0.1  4132.762920  39871528.0
# 3                 NaN         NaN       NaN          NaN         NaN
# 4                 NaN        64.0       1.9  3695.793748   2785935.0
# ..                ...         ...       ...          ...         ...
# 194               NaN        97.0       0.1          NaN         NaN
# 195               NaN        96.0       0.1          NaN         NaN
# 196               NaN        31.0       3.4   758.725782  11882136.0
# 197               NaN        99.0       0.1  3844.891230      2966.0
# 198               NaN        97.0       0.1          NaN         NaN
#
#      thinness1-19years  thinness5-9years  Incomecompositionofresources  \
# 0                 17.2              17.3                         0.479
# 1                  1.2               1.3                         0.762
# 2                  6.0               5.8                         0.743
# 3                  NaN               NaN                           NaN
# 4                  8.3               8.2                         0.531
# ..                 ...               ...                           ...
# 194                1.8               1.8                           NaN
# 195                4.9               4.9                           NaN
# 196                NaN               NaN                         0.421
# 197               15.1              15.0                         0.764
# 198               14.2              14.5                         0.678
#
#      Schooling
# 0         10.1
# 1         14.2
# 2         14.4
# 3          NaN
# 4         11.4
# ..         ...
# 194        NaN
# 195        NaN
# 196        4.9
# 197       14.0
# 198       12.6
#
# [199 rows x 26 columns]

# %%
combined_data=pd.merge(combined_df,happiness, on="Country",how='outer')
combined_data
# Out:
#                      Country  beer_servings  spirit_servings  wine_servings  \
# 0                Afghanistan            0.0              0.0            0.0
# 1                    Albania           89.0            132.0           54.0
# 2                    Algeria           25.0              0.0           14.0
# 3                    Andorra          245.0            138.0          312.0
# 4                     Angola          217.0             57.0           45.0
# ..                       ...            ...              ...            ...
# 202                   Taiwan            NaN              NaN            NaN
# 203                   Kosovo            NaN              NaN            NaN
# 204             North Cyprus            NaN              NaN            NaN
# 205                Hong Kong            NaN              NaN            NaN
# 206  Palestinian Territories            NaN              NaN            NaN
#
#      total_litres_of_pure_alcohol    Year      Status  Lifeexpectancy  \
# 0                             0.0  2015.0  Developing            65.0
# 1                             4.9  2015.0  Developing            77.8
# 2                             0.7  2015.0  Developing            75.6
# 3                            12.4     NaN         NaN             NaN
# 4                             5.9  2015.0  Developing            52.4
# ..                            ...     ...         ...             ...
# 202                           NaN     NaN         NaN             NaN
# 203                           NaN     NaN         NaN             NaN
# 204                           NaN     NaN         NaN             NaN
# 205                           NaN     NaN         NaN             NaN
# 206                           NaN     NaN         NaN             NaN
#
#      AdultMortality  infantdeaths  ...  Generosity  Perceptions of corruption  \
# 0             263.0          62.0  ...   -0.096429                   0.933687
# 1              74.0           0.0  ...   -0.042309                   0.896304
# 2              19.0          21.0  ...   -0.121105                   0.735485
# 3               NaN           NaN  ...         NaN                        NaN
# 4             335.0          66.0  ...         NaN                        NaN
# ..              ...           ...  ...         ...                        ...
# 202             NaN           NaN  ...   -0.073199                   0.731883
# 203             NaN           NaN  ...    0.190934                   0.922328
# 204             NaN           NaN  ...    0.000227                   0.626116
# 205             NaN           NaN  ...    0.134980                   0.420607
# 206             NaN           NaN  ...   -0.162079                   0.824200
#
#      Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 0                    1.972317                          0.300706
# 1                    1.972317                          0.906653
# 2                    1.972317                          0.943856
# 3                         NaN                               NaN
# 4                         NaN                               NaN
# ..                        ...                               ...
# 202                  1.972317                          1.327471
# 203                  1.972317                          0.840481
# 204                  1.972317                          1.212799
# 205                  1.972317                          1.376746
# 206                  1.972317                          0.587819
#
#      Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                        0.356434                               0.266052
# 1                        0.830484                               0.846330
# 2                        1.143004                               0.745419
# 3                             NaN                                    NaN
# 4                             NaN                                    NaN
# ..                            ...                                    ...
# 202                      1.357761                               0.878438
# 203                      1.183963                               0.672709
# 204                      1.183089                               1.026125
# 205                      1.243584                               1.136631
# 206                      1.194756                               0.613827
#
#      Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                      0.000000                  0.135235
# 1                                      0.461946                  0.171028
# 2                                      0.083944                  0.118915
# 3                                           NaN                       NaN
# 4                                           NaN                       NaN
# ..                                          ...                       ...
# 202                                    0.449404                  0.150599
# 203                                    0.557280                  0.325287
# 204                                    0.477886                  0.199160
# 205                                    0.459357                  0.288281
# 206                                    0.298701                  0.091816
#
#      Explained by: Perceptions of corruption  Dystopia + residual
# 0                                   0.001226             1.507236
# 1                                   0.025361             1.640897
# 2                                   0.129191             1.840812
# 3                                        NaN                  NaN
# 4                                        NaN                  NaN
# ..                                       ...                  ...
# 202                                 0.131516             2.160239
# 203                                 0.008559             2.736903
# 204                                 0.199803             1.236688
# 205                                 0.332485             0.673293
# 206                                 0.071914             1.693986
#
# [207 rows x 45 columns]

# %%
combined_data.to_csv('Resources/Data/combined_data.csv')
