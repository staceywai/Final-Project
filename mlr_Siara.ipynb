# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read the csv file into a pandas DataFrame

data = pd.read_csv('Resources/Data/scaled_data.csv')
data.head()
# Out:
#    Unnamed: 0  Happiness_Score       GDP  Social_Support  \
# 0           0         1.000000  0.929138        0.979132
# 1           1         0.979113  0.940905        0.980836
# 2           2         0.968138  0.958889        0.967350
# 3           3         0.961043  0.940779        1.000000
# 4           4         0.958930  0.968310        0.977240
#
#    Life_Expectancy (Happiness)  Freedom_Score  Generosity  Corruption_Score  \
# 0                     0.936153       0.973512   -0.106092          0.208901
# 1                     0.942685       0.975842    0.118077          0.180090
# 2                     0.964818       0.944962    0.188903          0.324640
# 3                     0.950464       0.973224    0.440450          0.760711
# 4                     0.953078       0.980259    0.239952          0.281341
#
#    Happiness (Dystopia)  Beer_Servings  ...  under-fivedeaths     Polio  \
# 0                   1.0       0.699468  ...               0.0  0.979798
# 1                   1.0       0.595745  ...               0.0  0.939394
# 2                   1.0       0.492021  ...               0.0  0.979798
# 3                   1.0       0.619681  ...               0.0  0.929293
# 4                   1.0       0.449468  ...               0.0  0.959596
#
#    Diphtheria  HIV/AIDS     GDP.1  Population  thinness1-19years  \
# 0    0.979798  0.010753  0.075068    0.021225           0.033708
# 1    0.939394  0.010753  0.093974    0.022015           0.041199
# 2    0.979798  0.010753  0.158959    0.032082           0.014981
# 3    0.929293  0.010753  0.101397    0.000131           0.037453
# 4    0.959596  0.010753  0.131824    0.002010           0.029963
#
#    thinness5-9years       HDI  Schooling
# 0          0.029304  0.941983   0.833333
# 1          0.032967  0.973629   0.941176
# 2          0.010989  0.989451   0.784314
# 3          0.032967  0.969409   0.931373
# 4          0.025641  1.000000   0.867647
#
# [5 rows x 30 columns]

# %%
data.rename(columns = {'Unnamed: 0':'country_id'}, inplace = True)
data.head()
# Out:
#    country_id  Happiness_Score       GDP  Social_Support  \
# 0           0         1.000000  0.929138        0.979132
# 1           1         0.979113  0.940905        0.980836
# 2           2         0.968138  0.958889        0.967350
# 3           3         0.961043  0.940779        1.000000
# 4           4         0.958930  0.968310        0.977240
#
#    Life_Expectancy (Happiness)  Freedom_Score  Generosity  Corruption_Score  \
# 0                     0.936153       0.973512   -0.106092          0.208901
# 1                     0.942685       0.975842    0.118077          0.180090
# 2                     0.964818       0.944962    0.188903          0.324640
# 3                     0.950464       0.973224    0.440450          0.760711
# 4                     0.953078       0.980259    0.239952          0.281341
#
#    Happiness (Dystopia)  Beer_Servings  ...  under-fivedeaths     Polio  \
# 0                   1.0       0.699468  ...               0.0  0.979798
# 1                   1.0       0.595745  ...               0.0  0.939394
# 2                   1.0       0.492021  ...               0.0  0.979798
# 3                   1.0       0.619681  ...               0.0  0.929293
# 4                   1.0       0.449468  ...               0.0  0.959596
#
#    Diphtheria  HIV/AIDS     GDP.1  Population  thinness1-19years  \
# 0    0.979798  0.010753  0.075068    0.021225           0.033708
# 1    0.939394  0.010753  0.093974    0.022015           0.041199
# 2    0.979798  0.010753  0.158959    0.032082           0.014981
# 3    0.929293  0.010753  0.101397    0.000131           0.037453
# 4    0.959596  0.010753  0.131824    0.002010           0.029963
#
#    thinness5-9years       HDI  Schooling
# 0          0.029304  0.941983   0.833333
# 1          0.032967  0.973629   0.941176
# 2          0.010989  0.989451   0.784314
# 3          0.032967  0.969409   0.931373
# 4          0.025641  1.000000   0.867647
#
# [5 rows x 30 columns]

# %%
data.columns
# Out:
# Index(['country_id', 'Happiness_Score', 'GDP', 'Social_Support',
#        'Life_Expectancy (Happiness)', 'Freedom_Score', 'Generosity',
#        'Corruption_Score', 'Happiness (Dystopia)', 'Beer_Servings',
#        'Spirit_Servings', 'Wine_Servings', 'Total_L_Pure_Alcohol',
#        'Life_Expectancy (LED)', 'Adult_Mortality', 'infantdeaths',
#        'GDP_Health_Gov_Expenditure (%)', 'HepatitisB', 'Measles', 'BMI',
#        'under-fivedeaths', 'Polio', 'Diphtheria', 'HIV/AIDS', 'GDP.1',
#        'Population', 'thinness1-19years', 'thinness5-9years', 'HDI',
#        'Schooling'],
#       dtype='object')

# %%
 # Assign the data to X and y

X = data[['GDP', 'Social_Support',
       'Life_Expectancy (Happiness)', 'Freedom_Score', 'Generosity',
       'Corruption_Score', 'Beer_Servings',
       'Spirit_Servings', 'Wine_Servings',
       'Life_Expectancy (LED)', 'Adult_Mortality',
       'GDP_Health_Gov_Expenditure (%)', 'HepatitisB', 'Measles', 'BMI',
       'under-fivedeaths', 'Polio', 'Diphtheria', 'HIV/AIDS',
       'Population', 'thinness1-19years',
       'Schooling']]
y = data['Happiness_Score'].values.reshape(-1, 1)
print(X.shape, y.shape)
# Out:
# (155, 22) (155, 1)

# %%
 # Use train_test_split to create training and testing data

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
 # Create the model using LinearRegression

from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
 # Fit the model to the training data and calculate the scores for the training and testing data

model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.8237123595817561
# Testing Score: 0.7165538147803847

# %%
# Plot the Residuals for the Training and Testing data

plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="Training Data")
plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y.min(), xmax=y.max())
plt.title("Residual Plot")
# Out:
# Text(0.5, 1.0, 'Residual Plot')

# %%
coef = model.coef_
coef
# Out:
# array([[ 0.40718085,  0.18806981, -0.00495575,  0.26575282,  0.06213348,
#         -0.02728552,  0.07755851, -0.05720577,  0.01861509, -0.11062313,
#         -0.11336464, -0.09382895, -0.01110586, -0.21899163,  0.01517111,
#          0.2491003 , -0.11420669,  0.05200165, -0.16046105, -0.16456641,
#         -0.25499966,  0.00504559]])

# %%
# Coefficients. In simple or multiple linear regression, the size of the coefficient for each independent variable 
# gives you the size of the effect that variable is having on your dependent variable, and the sign on the coefficient 
# (positive or negative) gives you the direction of the effect.
